# %%
import requests
import numpy as np
import pandas as pd

city = "Lyon"
start_date = "2023-01-01"
end_date = "2023-02-01"
key = "534887c399c84ceaa49ed2e322168f29"

cool_features = ['wind_spd', 'temp', 'max_temp', 'min_temp', 'clouds', 'precip', 'snow_depth']

url = f"https://api.weatherbit.io/v2.0/history/daily?city={city}&start_date={start_date}&end_date={end_date}&key={key}"
r = requests.get(url)

data = r.json()

# %%
full_df = pd.DataFrame(data['data'])
full_df[['wind_spd', 'temp', 'max_temp', 'min_temp', 'clouds', 'precip', 'snow_depth']].mean()
# Out:
# wind_spd       4.109677
# temp           5.570968
# max_temp       7.903226
# min_temp       2.709677
# clouds        75.774194
# precip         1.790323
# snow_depth          NaN
# dtype: float64

# %%
monthly_df = pd.DataFrame(full_df[['wind_spd', 'temp', 'max_temp', 'min_temp', 'clouds', 'precip', 'snow_depth']].mean()).T

# %%
monthly_df["city_name"] = data["city_name"]
monthly_df["year"] = data['data'][0]['datetime'].split('-')[0]
monthly_df["month"] = data['data'][0]['datetime'].split('-')[1]

# %%
monthly_df
# Out:
#    wind_spd      temp  max_temp  min_temp     clouds    precip  snow_depth  \
# 0  4.109677  5.570968  7.903226  2.709677  75.774194  1.790323         NaN
#
#   city_name  year month
# 0      Lyon  2023    01

# %%
citipd.read_csv("Hiking_data.csv", encoding='latin-1')
# Out:
#       1.ID Country Most accurate location                      Region  \
# 0        0  France    Chamonix-Mont-Blanc        Auvergne Rhône Alpes
# 1        1  France   Berrias-Et-Casteljau        Auvergne Rhône Alpes
# 2        2  France      Talloires-Montmin        Auvergne Rhône Alpes
# 3        3  France                 Vénosc        Auvergne Rhône Alpes
# 4        4  France                Orcines        Auvergne Rhône Alpes
# ...    ...     ...                    ...                         ...
# 1195  1195     NaN                    NaN                         NaN
# 1196  1196     NaN                    NaN                         NaN
# 1197  1197     NaN                    NaN                         NaN
# 1198  1198  France            Montgenèvre  Provence-Alpes-Côte D'Azur
# 1199  1199     NaN                    NaN                         NaN
#
#                                                     url
# 0     https://www.komoot.com/smarttour/e934061622/de...
# 1     https://www.komoot.com/smarttour/e1035103613/p...
# 2     https://www.komoot.com/smarttour/e934332802/le...
# 3     https://www.komoot.com/smarttour/e1026981424/l...
# 4     https://www.komoot.com/smarttour/e930384063/pu...
# ...                                                 ...
# 1195  https://www.komoot.com/smarttour/15226901?tour...
# 1196  https://www.komoot.com/smarttour/4093337?tour_...
# 1197  https://www.komoot.com/smarttour/15233541?tour...
# 1198  https://www.komoot.com/smarttour/1498498?tour_...
# 1199  https://www.komoot.com/smarttour/7064823?tour_...
#
# [1200 rows x 5 columns]
